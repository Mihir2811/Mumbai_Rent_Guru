# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Indian_housing_Mumbai_data.csv')

# %%
data.describe()
# Out:
#           latitude    longitude         price  numBathrooms  numBalconies  \
# count  5000.000000  5000.000000  5.000000e+03   4986.000000    733.000000
# mean     19.159138    72.953226  6.239421e+04      2.033895      2.064120
# std       0.435495     0.564369  8.874473e+04      0.800861      1.095187
# min      17.468220    72.719688  2.800000e+03      1.000000      1.000000
# 25%      19.070265    72.839161  2.100000e+04      2.000000      1.000000
# 50%      19.128770    72.884460  4.000000e+04      2.000000      2.000000
# 75%      19.195199    72.995323  7.000000e+04      2.000000      3.000000
# max      30.888254    91.792137  1.200000e+06      7.000000      6.000000
#
#        priceSqFt
# count        0.0
# mean         NaN
# std          NaN
# min          NaN
# 25%          NaN
# 50%          NaN
# 75%          NaN
# max          NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   house_type        5000 non-null   object
#  1   house_size        5000 non-null   object
#  2   location          5000 non-null   object
#  3   city              5000 non-null   object
#  4   latitude          5000 non-null   float64
#  5   longitude         5000 non-null   float64
#  6   price             5000 non-null   int64
#  7   currency          5000 non-null   object
#  8   numBathrooms      4986 non-null   float64
#  9   numBalconies      733 non-null    float64
#  10  isNegotiable      571 non-null    object
#  11  priceSqFt         0 non-null      float64
#  12  verificationDate  5000 non-null   object
#  13  description       4922 non-null   object
#  14  SecurityDeposit   5000 non-null   object
#  15  Status            5000 non-null   object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 625.1+ KB

# %%
data.shape
# Out:
# (5000, 16)

# %%
data.drop('latitude',inplace=True,axis=1)

# %%
data.drop('longitude',inplace=True,axis=1)
data.drop('isNegotiable',inplace=True,axis=1)
data.drop('priceSqFt',inplace=True,axis=1)
data.drop('description',inplace=True,axis=1)
data.drop('currency',inplace=True,axis=1)
data.drop('city',inplace=True,axis=1)

# %%
data.describe()
# Out:
#               price  numBathrooms  numBalconies
# count  5.000000e+03   4986.000000    733.000000
# mean   6.239421e+04      2.033895      2.064120
# std    8.874473e+04      0.800861      1.095187
# min    2.800000e+03      1.000000      1.000000
# 25%    2.100000e+04      2.000000      1.000000
# 50%    4.000000e+04      2.000000      2.000000
# 75%    7.000000e+04      2.000000      3.000000
# max    1.200000e+06      7.000000      6.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   house_type        5000 non-null   object
#  1   house_size        5000 non-null   object
#  2   location          5000 non-null   object
#  3   price             5000 non-null   int64
#  4   numBathrooms      4986 non-null   float64
#  5   numBalconies      733 non-null    float64
#  6   verificationDate  5000 non-null   object
#  7   SecurityDeposit   5000 non-null   object
#  8   Status            5000 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 351.7+ KB

# %%
data.isnull().sum()
# Out:
# house_type             0
# house_size             0
# location               0
# price                  0
# numBathrooms          14
# numBalconies        4267
# verificationDate       0
# SecurityDeposit        0
# Status                 0
# dtype: int64

# %%
data['numBathrooms'].fillna(data['numBathrooms'].mean(), inplace=True)

# %%
data['numBathrooms'].unique()
# Out:
# array([2.        , 3.        , 1.        , 4.        , 5.        ,
#        6.        , 2.03389491, 7.        ])

# %%
data['numBalconies'].unique()
# Out:
# array([nan,  2.,  4.,  1.,  5.,  6.,  3.])

# %%
data['numBalconies'].fillna(0, inplace=True)

# %%
data['numBalconies'].unique()
# Out:
# array([0., 2., 4., 1., 5., 6., 3.])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   house_type        5000 non-null   object
#  1   house_size        5000 non-null   object
#  2   location          5000 non-null   object
#  3   price             5000 non-null   int64
#  4   numBathrooms      5000 non-null   float64
#  5   numBalconies      5000 non-null   float64
#  6   verificationDate  5000 non-null   object
#  7   SecurityDeposit   5000 non-null   object
#  8   Status            5000 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 351.7+ KB

# %%
data.isnull().sum()
# Out:
# house_type          0
# house_size          0
# location            0
# price               0
# numBathrooms        0
# numBalconies        0
# verificationDate    0
# SecurityDeposit     0
# Status              0
# dtype: int64

# %%
data.head(5)
# Out:
#          house_type   house_size        location  price  numBathrooms  \
# 0  2 BHK Apartment   1,180 sq ft            Ulwe  19000           2.0
# 1  2 BHK Apartment   1,120 sq ft            Ulwe  12500           2.0
# 2  2 BHK Apartment   1,200 sq ft          Panvel  22000           2.0
# 3  2 BHK Apartment     750 sq ft  Kandivali West  28500           2.0
# 4  3 BHK Apartment   1,400 sq ft         Chembur  50000           3.0
#
#    numBalconies    verificationDate SecurityDeposit          Status
# 0           0.0  Posted 2 years ago      No Deposit       Furnished
# 1           0.0  Posted 2 years ago      No Deposit     Unfurnished
# 2           0.0  Posted a month ago      No Deposit     Unfurnished
# 3           0.0  Posted 3 years ago      No Deposit     Unfurnished
# 4           0.0  Posted 3 years ago      No Deposit  Semi-Furnished

# %% [markdown]
# # Data is now free from null values
# Now we will remove the extra symbols from interger values

# %%
data['house_type'].head()
# Out:
# 0    2 BHK Apartment
# 1    2 BHK Apartment
# 2    2 BHK Apartment
# 3    2 BHK Apartment
# 4    3 BHK Apartment
# Name: house_type, dtype: object

# %%
data['house_type'].unique()
# Out:
# array(['2 BHK Apartment ', '3 BHK Apartment ', '1 RK Studio Apartment ',
#        '1 BHK Apartment ', '4 BHK Apartment ', '1 BHK Independent Floor ',
#        '3 BHK Villa ', '3 BHK Independent House ',
#        '4 BHK Independent House ', '4 BHK Villa ', '6 BHK Apartment ',
#        '2 BHK Independent House ', '5 BHK Apartment ', '1 BHK Villa ',
#        '4 BHK Independent Floor ', '6 BHK Villa ', '5 BHK Villa ',
#        '3 BHK Independent Floor ', '2 BHK Independent Floor ',
#        '6 BHK penthouse ', '1 BHK Independent House '], dtype=object)

# %%
data['house_type'] = data['house_type'].str.replace(' ','')

# %%
data['house_size'].head()
# Out:
# 0    1,180 sq ft
# 1    1,120 sq ft
# 2    1,200 sq ft
# 3      750 sq ft
# 4    1,400 sq ft
# Name: house_size, dtype: object

# %%
data['house_size'].str.split()
# Out:
# 0       [1,180, sq, ft]
# 1       [1,120, sq, ft]
# 2       [1,200, sq, ft]
# 3         [750, sq, ft]
# 4       [1,400, sq, ft]
#              ...
# 4995      [800, sq, ft]
# 4996    [1,200, sq, ft]
# 4997    [1,040, sq, ft]
# 4998    [1,930, sq, ft]
# 4999    [1,260, sq, ft]
# Name: house_size, Length: 5000, dtype: object

# %%
data['house_size'].str.split().str.get(0)
# Out:
# 0       1,180
# 1       1,120
# 2       1,200
# 3         750
# 4       1,400
#         ...
# 4995      800
# 4996    1,200
# 4997    1,040
# 4998    1,930
# 4999    1,260
# Name: house_size, Length: 5000, dtype: object

# %%
data['house_size'] = data['house_size'].str.split().str.get(0).str.replace(',','')
data['house_size'].head(8)
# Out:
# 0    1180
# 1    1120
# 2    1200
# 3     750
# 4    1400
# 5     450
# 6     700
# 7     600
# Name: house_size, dtype: object

# %%
data['location'].unique()
# Out:
# array(['Ulwe', 'Panvel', 'Kandivali West', 'Chembur', 'Badlapur East',
#        'Dombivali', 'Bandra West', 'Andheri East', 'Bhayandar East',
#        'Goregaon West', 'Colaba', 'Kalamboli', 'Palghar', 'Nerul',
#        'Kandivali East', 'Sion', 'Andheri West', 'Juhu', 'Vasai',
#        'Thakurli', 'Powai', 'Jogeshwari East', 'Mira Road East',
#        'Thane West', 'Parel', 'Prabhadevi', 'Ghatkopar East',
#        'Kalyan West', 'Dadar East', 'vile parle west', 'Bhandup West',
#        'Borivali East', 'Mahalaxmi', 'Kanjurmarg', 'Seawoods',
#        'Dombivali East', 'Titwala', 'Karanjade', 'Girgaon',
#        'Malabar Hill', 'Dadar West', 'Goregaon East', 'Mahim', 'Sanpada',
#        'Mulund West', 'Tardeo', 'Malad East', 'Borivali West',
#        'Malad West', 'Kharghar', 'Jogeshwari West', 'Kamothe',
#        'Bandra East', 'Worli', 'Ville Parle East', 'Mulund East',
#        'Vikhroli', 'Ghatkopar West', 'Dombivli (West)', 'Cumballa Hill',
#        'Khar', 'Vevoor', 'Kanjurmarg East', 'Lower Parel', 'Marine Lines',
#        'Hiranandani Estates', 'Napeansea Road', 'Nala Sopara',
#        'Khar West', 'Byculla', 'Cuffe Parade', 'Matunga', 'Vasai east',
#        'MATUNGA WEST', 'Gamdevi', 'Agripada', 'Jacob Circle', 'Wadala',
#        'Sewri', 'Belapur', 'Airoli', 'Deonar', 'Dahisar West', 'Dahisar',
#        'Virar', 'Ghansoli', 'Boisar', 'Kalyan East', 'Churchgate',
#        'Kurla', 'Kurla East', 'Govandi', 'Tilak Nagar', 'Santosh Nagar',
#        'matunga east', 'Koper Khairane', 'Palava', 'Vashi',
#        'Santacruz West', 'Santacruz East', 'Bhayandar West',
#        'Bandra Kurla Complex', 'Dharamveer Nagar', 'Nalasopara West',
#        'Kalwa', 'Ville Parle West', 'Antarli', 'Shil Phata',
#        'Amrut Nagar', 'Virar East', 'Sector 21 Kamothe', 'Naigaon East',
#        'Khardi', 'Diva Gaon', 'Diva', 'Vasai West', 'Koproli', 'DN Nagar',
#        'Ambernath West', 'St Andrew Rd', 'Balkum', 'CBD Belapur East',
#        'Borivali (West)', 'Breach Candy', 'Sector 21 Ghansoli',
#        'Sector6 Kopar Khairane', 'Bhandup East', 'Parel Village',
#        'Pali Hill', 'Juhu Tara Rd', 'Juhu Scheme', 'Ghansoli Gaon',
#        'Mahape', 'Koparkhairane Station Road', 'Sector 5 Ghansoli',
#        'Mahim West', 'Marol andheri east', 'Badlapur West', 'juhu tara',
#        'Rasayani', 'Bhiwandi', 'Versova', 'Yari Road',
#        'colaba post office', 'Aarya Chanakya Nagar', 'Akurli Road',
#        'Akurli Road Number 1', 'Sector-15 Ghansoli', 'Walkeshwar',
#        'Sector-16 Koparkhairane', 'Carter Road', 'Marine Drive',
#        'Kasar vadavali', 'Sakinaka Andheri east', 'Ambernath East',
#        'Lokhandwala', 'nallasopara W', 'Seven Bunglow', 'Babhai Naka',
#        'Babhai', 'Kastur Park', 'yogi nagar',
#        'Jayraj Nagar near Yogi Nagar', 'Rabale', 'Virar West',
#        'Devidas Cross Lane', 'Devidas Rd', 'Ghodbunder Road',
#        'Kurla West', 'Piramal Nagar Housing Society Road', 'Taloja',
#        'Suyog Nagar', 'Hendre Pada', 'Peddar Road',
#        'Sector-19 Koper Khairane', 'Majiwada thane', 'karanjade panvel',
#        'Saphale', 'Syndicate', 'Sector5 Kopar Khairane',
#        'Nalasopara East', 'Gulmohar Road', 'Dahisar East',
#        'vakola santacuz e', 'Dharavi', 'Kapurbawadi', 'Vakola',
#        'Sector 12 Kharghar', 'Saki Naka'], dtype=object)

# %% [markdown]
# *   type done
# *   size done
# *   location done

# %%
data.head(5)
# Out:
#       house_type house_size        location  price  numBathrooms  \
# 0  2BHKApartment       1180            Ulwe  19000           2.0
# 1  2BHKApartment       1120            Ulwe  12500           2.0
# 2  2BHKApartment       1200          Panvel  22000           2.0
# 3  2BHKApartment        750  Kandivali West  28500           2.0
# 4  3BHKApartment       1400         Chembur  50000           3.0
#
#    numBalconies    verificationDate SecurityDeposit          Status
# 0           0.0  Posted 2 years ago      No Deposit       Furnished
# 1           0.0  Posted 2 years ago      No Deposit     Unfurnished
# 2           0.0  Posted a month ago      No Deposit     Unfurnished
# 3           0.0  Posted 3 years ago      No Deposit     Unfurnished
# 4           0.0  Posted 3 years ago      No Deposit  Semi-Furnished

# %% [markdown]
# Changing type

# %%
data['numBathrooms'] = data['numBathrooms'].astype(int)
data['numBalconies'] = data['numBalconies'].astype(int)
data['house_size'] = data['house_size'].astype(int)

# %%
data['numBathrooms'].unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 7])

# %%
data['numBalconies'].unique()
# Out:
# array([0, 2, 4, 1, 5, 6, 3])

# %%
data['verificationDate'].unique()
# Out:
# array(['Posted 2 years ago', 'Posted a month ago', 'Posted 3 years ago',
#        'Posted 3 months ago', 'Posted 2 months ago', 'Posted 23 days ago',
#        'Posted 18 days ago', 'Posted 11 days ago', 'Posted 4 days ago',
#        'Posted a day ago', 'Posted 17 days ago', 'Posted 4 months ago',
#        'Posted 12 days ago', 'Posted 8 months ago', 'Posted a year ago',
#        'Posted 13 days ago', 'Posted 16 days ago', 'Posted 20 days ago',
#        'Posted 19 days ago', 'Posted 22 days ago', 'Posted 9 days ago',
#        'Posted 15 days ago', 'Posted 21 days ago', 'Posted 14 days ago',
#        'Posted 5 days ago', 'Posted 10 days ago', 'Posted 20 hours ago',
#        'Posted 8 days ago', 'Posted 2 days ago', 'Posted 24 days ago',
#        'Posted 3 days ago', 'Posted 25 days ago', 'Posted 7 days ago',
#        'Posted 6 days ago', 'Posted 17 hours ago', 'Posted 5 months ago',
#        'Posted 19 hours ago', 'Posted 16 hours ago',
#        'Posted 10 hours ago', 'Posted 4 years ago', 'Posted 21 hours ago',
#        'Posted 11 hours ago', 'Posted 18 hours ago',
#        'Posted 14 hours ago', 'Posted 10 months ago',
#        'Posted 9 months ago', 'Posted 6 months ago',
#        'Posted 13 hours ago', 'Posted 33 minutes ago',
#        'Posted an hour ago', 'Posted 5 years ago'], dtype=object)

# %%
data['verificationDate'] = data['verificationDate'].str.split().str.slice(1,3).str.join(' ')
data['verificationDate']
# Out:
# 0       2 years
# 1       2 years
# 2       a month
# 3       3 years
# 4       3 years
#          ...
# 4995     a year
# 4996     a year
# 4997     a year
# 4998     a year
# 4999     a year
# Name: verificationDate, Length: 5000, dtype: object

# %%
data.head(5)
# Out:
#       house_type  house_size        location  price  numBathrooms  \
# 0  2BHKApartment        1180            Ulwe  19000             2
# 1  2BHKApartment        1120            Ulwe  12500             2
# 2  2BHKApartment        1200          Panvel  22000             2
# 3  2BHKApartment         750  Kandivali West  28500             2
# 4  3BHKApartment        1400         Chembur  50000             3
#
#    numBalconies verificationDate SecurityDeposit          Status
# 0             0          2 years      No Deposit       Furnished
# 1             0          2 years      No Deposit     Unfurnished
# 2             0          a month      No Deposit     Unfurnished
# 3             0          3 years      No Deposit     Unfurnished
# 4             0          3 years      No Deposit  Semi-Furnished

# %% [markdown]
# *   type done
# *   size done
# *   location done
# *   price done
# *   bath done
# *   bal done
# *   veri done

# %%
data['SecurityDeposit'].unique()
# Out:
# array(['No Deposit', ' 2,50,000', ' 60,000', ' 1,00,000', ' 2,00,000',
#        ' 4,00,000', ' 3,00,000', ' 1,50,000', ' 1,25,000', ' 85,000',
#        ' 6,00,000', ' 75,000', ' 50,000', ' 25,000', ' 1,80,000',
#        ' 95,000', ' 5,00,000', ' 30,000', ' 90,000', ' 10,000',
#        ' 60,00,000', ' 50,00,000', ' 36,00,000', ' 42,00,000',
#        ' 18,00,000', ' 1,60,000', ' 45,000', ' 40,000', ' 35,000',
#        ' 80,000', ' 2,500', ' 20,000', ' 1,10,000', ' 21,00,000',
#        ' 8,00,000', ' 70,000', ' 65,000', ' 4,50,000', ' 10,00,000',
#        ' 2,75,000', ' 9,00,000', ' 12,000', ' 1,45,000', ' 7,50,000',
#        ' 15,000', ' 3,50,000', ' 12,00,000', ' 7,00,000', ' 5,50,000',
#        ' 20,00,000', ' 15,00,000', ' 11,00,000', ' 1,40,000', ' 1,20,000',
#        ' 1,65,000', ' 1,35,000', ' 55,000', ' 1,75,000', ' 3,500',
#        ' 13,000', ' 30,800', ' 30,200', ' 30,500', ' 30,600', ' 30,400',
#        ' 5,40,000', ' 7,000', ' 1,12,000', ' 2,20,000', ' 48,000',
#        ' 1,30,000', ' 21,000', ' 2,25,000', ' 1,00,080', ' 22,000',
#        ' 2,40,000'], dtype=object)

# %%
data['SecurityDeposit'] = data['SecurityDeposit'].str.replace('No Deposit', '0')

# %%
data['SecurityDeposit'] = data['SecurityDeposit'].str.replace(',','')

# %%
data['SecurityDeposit'] = data['SecurityDeposit'].astype(int)

# %%
data['SecurityDeposit'].unique()
# Out:
# array([      0,  250000,   60000,  100000,  200000,  400000,  300000,
#         150000,  125000,   85000,  600000,   75000,   50000,   25000,
#         180000,   95000,  500000,   30000,   90000,   10000, 6000000,
#        5000000, 3600000, 4200000, 1800000,  160000,   45000,   40000,
#          35000,   80000,    2500,   20000,  110000, 2100000,  800000,
#          70000,   65000,  450000, 1000000,  275000,  900000,   12000,
#         145000,  750000,   15000,  350000, 1200000,  700000,  550000,
#        2000000, 1500000, 1100000,  140000,  120000,  165000,  135000,
#          55000,  175000,    3500,   13000,   30800,   30200,   30500,
#          30600,   30400,  540000,    7000,  112000,  220000,   48000,
#         130000,   21000,  225000,  100080,   22000,  240000])

# %%
data['Status'].unique()
# Out:
# array(['Furnished', 'Unfurnished', 'Semi-Furnished'], dtype=object)

# %% [markdown]
# # Data is Now cleaned and ready for modeling

# %%
data.to_csv('cleaned_data.csv')

# %%
data
# Out:
#          house_type  house_size        location  price  numBathrooms  \
# 0     2BHKApartment        1180            Ulwe  19000             2
# 1     2BHKApartment        1120            Ulwe  12500             2
# 2     2BHKApartment        1200          Panvel  22000             2
# 3     2BHKApartment         750  Kandivali West  28500             2
# 4     3BHKApartment        1400         Chembur  50000             3
# ...             ...         ...             ...    ...           ...
# 4995  2BHKApartment         800       Saki Naka  46000             2
# 4996  2BHKApartment        1200      Malad West  55000             2
# 4997  2BHKApartment        1040   Goregaon West  44000             2
# 4998  3BHKApartment        1930        Kharghar  65000             3
# 4999  2BHKApartment        1260        Kharghar  31500             2
#
#       numBalconies verificationDate  SecurityDeposit          Status
# 0                0          2 years                0       Furnished
# 1                0          2 years                0     Unfurnished
# 2                0          a month                0     Unfurnished
# 3                0          3 years                0     Unfurnished
# 4                0          3 years                0  Semi-Furnished
# ...            ...              ...              ...             ...
# 4995             0           a year           150000     Unfurnished
# 4996             0           a year           250000  Semi-Furnished
# 4997             0           a year           200000     Unfurnished
# 4998             0           a year           200000       Furnished
# 4999             1           a year            80000  Semi-Furnished
#
# [5000 rows x 9 columns]

# %% [markdown]
# # Modeling

# %%
x = data.drop(columns = 'price')
y = data['price']

# %%
x.head(5)
# Out:
#       house_type  house_size        location  numBathrooms  numBalconies  \
# 0  2BHKApartment        1180            Ulwe             2             0
# 1  2BHKApartment        1120            Ulwe             2             0
# 2  2BHKApartment        1200          Panvel             2             0
# 3  2BHKApartment         750  Kandivali West             2             0
# 4  3BHKApartment        1400         Chembur             3             0
#
#   verificationDate  SecurityDeposit          Status
# 0          2 years                0       Furnished
# 1          2 years                0     Unfurnished
# 2          a month                0     Unfurnished
# 3          3 years                0     Unfurnished
# 4          3 years                0  Semi-Furnished

# %%
y.head(5)
# Out:
# 0    19000
# 1    12500
# 2    22000
# 3    28500
# 4    50000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
hot = OneHotEncoder()
hot.fit(x[['house_type','location','verificationDate', 'Status']])
# Out:
# OneHotEncoder()

# %%
hot.categories_
# Out:
# [array(['1BHKApartment', '1BHKIndependentFloor', '1BHKIndependentHouse',
#         '1BHKVilla', '1RKStudioApartment', '2BHKApartment',
#         '2BHKIndependentFloor', '2BHKIndependentHouse', '3BHKApartment',
#         '3BHKIndependentFloor', '3BHKIndependentHouse', '3BHKVilla',
#         '4BHKApartment', '4BHKIndependentFloor', '4BHKIndependentHouse',
#         '4BHKVilla', '5BHKApartment', '5BHKVilla', '6BHKApartment',
#         '6BHKVilla', '6BHKpenthouse'], dtype=object),
#  array(['Aarya Chanakya Nagar', 'Agripada', 'Airoli', 'Akurli Road',
#         'Akurli Road Number 1', 'Ambernath East', 'Ambernath West',
#         'Amrut Nagar', 'Andheri East', 'Andheri West', 'Antarli', 'Babhai',
#         'Babhai Naka', 'Badlapur East', 'Badlapur West', 'Balkum',
#         'Bandra East', 'Bandra Kurla Complex', 'Bandra West', 'Belapur',
#         'Bhandup East', 'Bhandup West', 'Bhayandar East', 'Bhayandar West',
#         'Bhiwandi', 'Boisar', 'Borivali (West)', 'Borivali East',
#         'Borivali West', 'Breach Candy', 'Byculla', 'CBD Belapur East',
#         'Carter Road', 'Chembur', 'Churchgate', 'Colaba', 'Cuffe Parade',
#         'Cumballa Hill', 'DN Nagar', 'Dadar East', 'Dadar West', 'Dahisar',
#         'Dahisar East', 'Dahisar West', 'Deonar', 'Devidas Cross Lane',
#         'Devidas Rd', 'Dharamveer Nagar', 'Dharavi', 'Diva', 'Diva Gaon',
#         'Dombivali', 'Dombivali East', 'Dombivli (West)', 'Gamdevi',
#         'Ghansoli', 'Ghansoli Gaon', 'Ghatkopar East', 'Ghatkopar West',
#         'Ghodbunder Road', 'Girgaon', 'Goregaon East', 'Goregaon West',
#         'Govandi', 'Gulmohar Road', 'Hendre Pada', 'Hiranandani Estates',
#         'Jacob Circle', 'Jayraj Nagar near Yogi Nagar', 'Jogeshwari East',
#         'Jogeshwari West', 'Juhu', 'Juhu Scheme', 'Juhu Tara Rd',
#         'Kalamboli', 'Kalwa', 'Kalyan East', 'Kalyan West', 'Kamothe',
#         'Kandivali East', 'Kandivali West', 'Kanjurmarg',
#         'Kanjurmarg East', 'Kapurbawadi', 'Karanjade', 'Kasar vadavali',
#         'Kastur Park', 'Khar', 'Khar West', 'Khardi', 'Kharghar',
#         'Koparkhairane Station Road', 'Koper Khairane', 'Koproli', 'Kurla',
#         'Kurla East', 'Kurla West', 'Lokhandwala', 'Lower Parel',
#         'MATUNGA WEST', 'Mahalaxmi', 'Mahape', 'Mahim', 'Mahim West',
#         'Majiwada thane', 'Malabar Hill', 'Malad East', 'Malad West',
#         'Marine Drive', 'Marine Lines', 'Marol andheri east', 'Matunga',
#         'Mira Road East', 'Mulund East', 'Mulund West', 'Naigaon East',
#         'Nala Sopara', 'Nalasopara East', 'Nalasopara West',
#         'Napeansea Road', 'Nerul', 'Palava', 'Palghar', 'Pali Hill',
#         'Panvel', 'Parel', 'Parel Village', 'Peddar Road',
#         'Piramal Nagar Housing Society Road', 'Powai', 'Prabhadevi',
#         'Rabale', 'Rasayani', 'Saki Naka', 'Sakinaka Andheri east',
#         'Sanpada', 'Santacruz East', 'Santacruz West', 'Santosh Nagar',
#         'Saphale', 'Seawoods', 'Sector 12 Kharghar', 'Sector 21 Ghansoli',
#         'Sector 21 Kamothe', 'Sector 5 Ghansoli', 'Sector-15 Ghansoli',
#         'Sector-16 Koparkhairane', 'Sector-19 Koper Khairane',
#         'Sector5 Kopar Khairane', 'Sector6 Kopar Khairane',
#         'Seven Bunglow', 'Sewri', 'Shil Phata', 'Sion', 'St Andrew Rd',
#         'Suyog Nagar', 'Syndicate', 'Taloja', 'Tardeo', 'Thakurli',
#         'Thane West', 'Tilak Nagar', 'Titwala', 'Ulwe', 'Vakola', 'Vasai',
#         'Vasai West', 'Vasai east', 'Vashi', 'Versova', 'Vevoor',
#         'Vikhroli', 'Ville Parle East', 'Ville Parle West', 'Virar',
#         'Virar East', 'Virar West', 'Wadala', 'Walkeshwar', 'Worli',
#         'Yari Road', 'colaba post office', 'juhu tara', 'karanjade panvel',
#         'matunga east', 'nallasopara W', 'vakola santacuz e',
#         'vile parle west', 'yogi nagar'], dtype=object),
#  array(['10 days', '10 hours', '10 months', '11 days', '11 hours',
#         '12 days', '13 days', '13 hours', '14 days', '14 hours', '15 days',
#         '16 days', '16 hours', '17 days', '17 hours', '18 days',
#         '18 hours', '19 days', '19 hours', '2 days', '2 months', '2 years',
#         '20 days', '20 hours', '21 days', '21 hours', '22 days', '23 days',
#         '24 days', '25 days', '3 days', '3 months', '3 years',
#         '33 minutes', '4 days', '4 months', '4 years', '5 days',
#         '5 months', '5 years', '6 days', '6 months', '7 days', '8 days',
#         '8 months', '9 days', '9 months', 'a day', 'a month', 'a year',
#         'an hour'], dtype=object),
#  array(['Furnished', 'Semi-Furnished', 'Unfurnished'], dtype=object)]

# %%
column_trans = make_column_transformer((OneHotEncoder(categories = hot.categories_), ['house_type','location','verificationDate', 'Status']), remainder='passthrough')
# handle_unknown='ignore' you can use

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['1BHKApartment', '1BHKIndependentFloor', '1BHKIndependentHouse',
#        '1BHKVilla', '1RKStudioApartment', '2BHKApartment',
#        '2BHKIndependentFloor', '2BHKIndependentHouse', '3BHKApartment',
#        '3BHKIndependentFloor', '3BHKIndependentHouse', '3BHKVilla',
#        '4BHKApartmen...
#        '20 days', '20 hours', '21 days', '21 hours', '22 days', '23 days',
#        '24 days', '25 days', '3 days', '3 months', '3 years',
#        '33 minutes', '4 days', '4 months', '4 years', '5 days',
#        '5 months', '5 years', '6 days', '6 months', '7 days', '8 days',
#        '8 months', '9 days', '9 months', 'a day', 'a month', 'a year',
#        'an hour'], dtype=object),
#                                                            array(['Furnished', 'Semi-Furnished', 'Unfurnished'], dtype=object)]),
#                                  ['house_type', 'location', 'verificationDate',
#                                   'Status'])])

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans, lr)

# %%
pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(
#         2.66044340e+04,  7.76315709e+04,  4.76155330e+04,  9.76421835e+04,
#         6.26236681e+04,  4.76155341e+04,  2.78030074e+04,  1.26657435e+05,
#         2.56673820e+04,  1.25970407e+04,  6.26234771e+04,  9.45355935e+04,
#         2.26022234e+04,  3.11068378e+04,  2.77737526e+05,  5.66203340e+04,
#         2.56038684e+04,  1.17652771e+05,  2.26023386e+04,  1.64677784e+05,
#         1.75996818e+04,  2.76049794e+04,  1.03636038e+05,  9.76421845e+04,
#         1.25969264e+04,  3.60749014e+04,  5.26182344e+04,  2.10637532e+05])

# %%
r2_score(ytest, y_pred)
# Out:
# 0.6096167381273958

# %%
mean_absolute_error(ytest, y_pred)
# Out:
# 34705.75736799734

# %%
mean_squared_error(ytest, y_pred)
# Out:
# 3880828268.639419

# %%
for i in range(10):
  xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)
  lr = LinearRegression()
  pipe = make_pipeline(column_trans, lr)
  pipe.fit(xtrain, ytrain)
  y_pred = pipe.predict(xtest)
  print(r2_score(ytest, y_pred))
# Out:
# 0.6648564159145676
# 0.688637905935342
# 0.501326223267094
# 0.5275703195322634
# 0.6511364552690582
# 0.5593911889377868
# 0.5474397331597098
# 0.5822687152373065
# 0.5211669507093548
# 0.4945931149776396

# %%
score = []

for i in range(1000):
  xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2, random_state=i)
  lr = LinearRegression()
  pipe = make_pipeline(column_trans, lr)
  pipe.fit(xtrain, ytrain)
  y_pred = pipe.predict(xtest)
  score.append(r2_score(ytest, y_pred))

# %%
np.argmax(score)
# Out:
# 121

# %%
score[np.argmax(score)]
# Out:
# 0.7624397705591778

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2, random_state=np.argmax(score))
lr = LinearRegression()
pipe = make_pipeline(column_trans, lr)
pipe.fit(xtrain, ytrain)
y_pred = pipe.predict(xtest)
print('R2 Score:',r2_score(ytest, y_pred))
print('Mean absolute error:',mean_absolute_error(ytest, y_pred))
print('Mean squared error:',mean_squared_error(ytest, y_pred))
# Out:
# R2 Score: 0.7624397705591778
# Mean absolute error: 29225.40577812229
# Mean squared error: 2012471391.300895

# %%
data.head(5)
# Out:
#       house_type  house_size        location  price  numBathrooms  \
# 0  2BHKApartment        1180            Ulwe  19000             2
# 1  2BHKApartment        1120            Ulwe  12500             2
# 2  2BHKApartment        1200          Panvel  22000             2
# 3  2BHKApartment         750  Kandivali West  28500             2
# 4  3BHKApartment        1400         Chembur  50000             3
#
#    numBalconies verificationDate  SecurityDeposit          Status
# 0             0          2 years                0       Furnished
# 1             0          2 years                0     Unfurnished
# 2             0          a month                0     Unfurnished
# 3             0          3 years                0     Unfurnished
# 4             0          3 years                0  Semi-Furnished

# %%
pipe.predict(pd.DataFrame([['1BHKApartment', 1180, 'Ulwe', 2, 0, '2 years', 0, 'Furnished']], columns=['house_type','house_size','location','numBathrooms','numBalconies','verificationDate','SecurityDeposit',	'Status']))
# Out:
# array([95226.27920819])

# %%
import pickle

# %%
pickle.dump(pipe, open('Model.py', 'wb'))
